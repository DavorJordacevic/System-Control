# %%
from scipy import signal

# %%
import scipy as sp

# %%
G = signal.lti([1], [1, 1.1,2])

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
t, u  = G.step()

# %%
plt.stem(t, u)
# Out:
# <Container object of 3 artists>

# %%
(0.65 - 0.5) / 0.5 * 100
# Out:
# 30.000000000000004

# %%
import numpy as np

# %%
type(u)
# Out:
# numpy.ndarray

# %%
np.max(u)
# Out:
# 0.63261374710401352

# %%
u > 0.1
# Out:
# array([False, False, False, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
plt.stem(t, u)
# Out:
# <Container object of 3 artists>

# %%
t_novo = np.arange(1000)

# %%
t_novo = t_novo / 100

# %%
t, u = G.step(T=t_novo)

# %%
plt.stem(t, u)
# Out:
# <Container object of 3 artists>

# %%
x = np.cos(1*2*np.pi*t)

# %%
t = np.arange(1000)
t = t/20

# %%
tout2,y1,y2 = signal.lsim(G,x,t)

# %%
plt.plot(tout2,y1,t,x)
